# %% [markdown]
# <a href="https://colab.research.google.com/github/24041511-a11y/probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https:github.com/Jose-Gabriel-Rodriguez/Probabilidad/blob/main/Cintilla2025.png?raw+true)
#
# # **Probabilidad y estadistica**
#
# ## **Unidad 1**
#
# ### **Practica 2. Maximo, minimo, Rango y dispersion de datos.**
#
# ### Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: David Zuñiga Rodriguez

# %%
# basado en el LIBRO de estadistica para administracion pagina 12
#creamos una lista vacia que representa la edad de 100 personas
import random
edades = []
# hacemos un ciclo para generar 100 numeros aleatorios que representen la edad de las personas
for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  # num_aleatorio
  numero_aleatorio = random.randint(18,70)
  # agregamos el numero aleatorio a la lista edades
  edades.append(numero_aleatorio)
  print(edades)
# Out:
# [64]
# [64, 49]
# [64, 49, 53]
# [64, 49, 53, 60]
# [64, 49, 53, 60, 57]
# [64, 49, 53, 60, 57, 25]
# [64, 49, 53, 60, 57, 25, 26]
# [64, 49, 53, 60, 57, 25, 26, 33]
# [64, 49, 53, 60, 57, 25, 26, 33, 45]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61, 24]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61, 24, 23]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61, 24, 23, 21]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61, 24, 23, 21, 47]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61, 24, 23, 21, 47, 29]
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61, 24, 23, 21, 47, 29, 62]
# ...

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los numeros aleatorios
df= pd.DataFrame(edades, columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      64
# 1      49
# 2      53
# 3      60
# 4      57

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de distribución de frecuencias")
tabla_frecuencias
# Out:
# Tabla de distribución de frecuencias
#     Edad  Frecuencia
# 14    18           3
# 39    20           1
# 10    21           3
# 43    22           1
# 5     23           4
# 11    24           3
# 8     25           3
# 7     26           3
# 27    27           2
# 15    28           3
# 17    29           3
# 22    31           2
# 18    32           2
# 29    33           1
# 44    34           1
# 32    35           1
# 31    36           1
# 35    37           1
# 38    39           1
# 25    41           2
# 40    42           1
# 42    43           1
# 24    44           2
# 4     45           4
# 30    46           1
# 9     47           3
# 23    48           2
# 0     49           6
# 41    50           1
# 21    51           2
# 19    52           2
# 1     53           5
# 36    56           1
# 3     57           4
# 34    58           1
# 2     60           4
# 6     61           3
# 12    62           3
# 28    64           1
# 37    65           1
# ...

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 14    18           3           0.03
# 39    20           1           0.01
# 10    21           3           0.03
# 43    22           1           0.01
# 5     23           4           0.04
# 11    24           3           0.03
# 8     25           3           0.03
# 7     26           3           0.03
# 27    27           2           0.02
# 15    28           3           0.03
# 17    29           3           0.03
# 22    31           2           0.02
# 18    32           2           0.02
# 29    33           1           0.01
# 44    34           1           0.01
# 32    35           1           0.01
# 31    36           1           0.01
# 35    37           1           0.01
# 38    39           1           0.01
# 25    41           2           0.02
# 40    42           1           0.01
# 42    43           1           0.01
# 24    44           2           0.02
# 4     45           4           0.04
# 30    46           1           0.01
# ...

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 14    18           3           0.03              3.0
# 39    20           1           0.01              1.0
# 10    21           3           0.03              3.0
# 43    22           1           0.01              1.0
# 5     23           4           0.04              4.0
# 11    24           3           0.03              3.0
# 8     25           3           0.03              3.0
# 7     26           3           0.03              3.0
# 27    27           2           0.02              2.0
# 15    28           3           0.03              3.0
# 17    29           3           0.03              3.0
# 22    31           2           0.02              2.0
# 18    32           2           0.02              2.0
# 29    33           1           0.01              1.0
# 44    34           1           0.01              1.0
# 32    35           1           0.01              1.0
# 31    36           1           0.01              1.0
# ...

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 14    18           3           0.03              3.0            0.03
# 39    20           1           0.01              1.0            0.01
# 10    21           3           0.03              3.0            0.03
# 43    22           1           0.01              1.0            0.01
# 5     23           4           0.04              4.0            0.04
# 11    24           3           0.03              3.0            0.03
# 8     25           3           0.03              3.0            0.03
# 7     26           3           0.03              3.0            0.03
# 27    27           2           0.02              2.0            0.02
# 15    28           3           0.03              3.0            0.03
# 17    29           3           0.03              3.0            0.03
# 22    31           2           0.02              2.0            0.02
# 18    32           2           0.02              2.0            0.02
# ...

# %%
#importamos la libreria de funciones aritmeticas
import math

# %%
#volvemos a usar la lista de edades
print(edades)
# Out:
# [64, 49, 53, 60, 57, 25, 26, 33, 45, 62, 52, 49, 68, 45, 61, 24, 23, 21, 47, 29, 62, 48, 36, 44, 25, 70, 69, 28, 23, 18, 29, 47, 32, 35, 24, 32, 60, 47, 62, 46, 41, 27, 49, 45, 57, 56, 49, 23, 28, 29, 48, 28, 69, 37, 67, 51, 61, 58, 39, 65, 23, 52, 49, 42, 61, 27, 53, 31, 21, 70, 60, 57, 53, 20, 45, 25, 50, 21, 44, 26, 43, 68, 18, 18, 53, 66, 70, 57, 22, 53, 60, 34, 41, 66, 66, 26, 31, 51, 49, 24]

# %%
# crear un DataFrame con la edades
df = pd.DataFrame({'edad': edades})
df
# Out:
#     edad
# 0     64
# 1     49
# 2     53
# 3     60
# 4     57
# ..   ...
# 95    26
# 96    31
# 97    51
# 98    49
# 99    24
#
# [100 rows x 1 columns]

# %%
# calcular el numero de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(n))
print("valor de n =", n, "nNumero de intervalos =", k)
# Out:
# valor de n = 100 nNumero de intervalos = 7

# %%
#crear la tabla de frecuencia
tabla_frecuencias = pd.cut(df['edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase', 'frecuencia']
tabla_frecuencias
# Out:
#               clase  frecuencia
# 0  (17.947, 25.429]          18
# 1  (47.714, 55.143]          18
# 2  (55.143, 62.571]          16
# 3  (25.429, 32.857]          15
# 4  (40.286, 47.714]          14
# 5    (62.571, 70.0]          13
# 6  (32.857, 40.286]           6

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencias = tabla_frecuencias.sort_values(by='clase')
display(tabla_frecuencias)
# Out:
#               clase  frecuencia
# 0  (17.947, 25.429]          18
# 3  (25.429, 32.857]          15
# 6  (32.857, 40.286]           6
# 4  (40.286, 47.714]          14
# 1  (47.714, 55.143]          18
# 2  (55.143, 62.571]          16
# 5    (62.571, 70.0]          13

# %%
# Genere\ar columnas siguientes
tabla_frecuencias ['Frec Rel'] = tabla_frecuencias ['frecuencia'] /n
tabla_frecuencias ['Frec Porc'] = tabla_frecuencias ['frecuencia'] / n * 100
tabla_frecuencias ['Frec Ac'] = tabla_frecuencias['frecuencia'].cumsum()
tabla_frecuencias ['Frec Rel Ac'] = tabla_frecuencias ['Frec Rel'].cumsum()
tabla_frecuencias [ 'Frec Porc Ac'] = tabla_frecuencias ['Frec Porc'].cumsum()
# Mostrar la tabla de frecuencia
print(tabla_frecuencias)
# Out:
#               clase  frecuencia  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 0  (17.947, 25.429]          18      0.18       18.0       18         0.18
# 3  (25.429, 32.857]          15      0.15       15.0       33         0.33
# 6  (32.857, 40.286]           6      0.06        6.0       39         0.39
# 4  (40.286, 47.714]          14      0.14       14.0       53         0.53
# 1  (47.714, 55.143]          18      0.18       18.0       71         0.71
# 2  (55.143, 62.571]          16      0.16       16.0       87         0.87
# 5    (62.571, 70.0]          13      0.13       13.0      100         1.00
#
#    Frec Porc Ac
# 0          18.0
# 3          33.0
# 6          39.0
# 4          53.0
# 1          71.0
# 2          87.0
# 5         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# crear un histograma basado en la tabla de frecuencia
plt.hist(df['edad'], bins=k, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
