# %% [markdown]
# <a href="https://colab.research.google.com/github/24041511-a11y/probabilidad/blob/main/Unidad3/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
#valores de la variable aleatoria
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.20,0.10]
#verificar suma = 1
print("suma de probabilidades",sum(p))
#Graficar distribucion
plt.stem(x,p)
plt.title("Distribucion de probabilidad")
plt.xlabel("Calificacion")
plt.ylabel("probabilidad")
plt.grid(True)
plt.show()
# Out:
# suma de probabilidades 0.9500000000000001
